# %%
import configparser
import os
vAR_Config = configparser.ConfigParser(allow_no_value=True)

vAR_INI_FILE_PATH = os.getenv('TIME_SERIES_INI_FILE_PATH')
#print(vAR_INI_FILE_PATH)

vAR_Config.read(vAR_INI_FILE_PATH)

vAR_Data = vAR_Config.sections()

vAR_Config.sections()

vAR_Training_Data = vAR_Config['FILE PATH']['TRAINING_DATA']
#print(vAR_Training_Data)

vAR_Test_Data = vAR_Config['FILE PATH']['TEST_DATA']
#print(vAR_Test_Data)

vAR_State1 = vAR_Config['STATES']['STATE1']
#print(vAR_State1)

vAR_State2 = vAR_Config['STATES']['STATE2']
#print(vAR_State2)

vAR_City1 = vAR_Config['CITIES']['CITY1']
#print(vAR_City2)

vAR_City2 = vAR_Config['CITIES']['CITY2']
#print(vAR_City2)

vAR_City3 = vAR_Config['CITIES']['CITY3']
#print(vAR_City3)

vAR_City4 = vAR_Config['CITIES']['CITY4']
#print(vAR_City4)

vAR_City5 = vAR_Config['CITIES']['CITY5']
#print(vAR_City5)

vAR_City6 = vAR_Config['CITIES']['CITY6']
#print(vAR_City6)

vAR_SKU1 = vAR_Config['SKU']['SKU1']
#print(vAR_SKU1)

vAR_SKU2 = vAR_Config['SKU']['SKU2']
#print(vAR_SKU2)

vAR_SKU3 = vAR_Config['SKU']['SKU3']
#print(vAR_SKU3)

vAR_SKU4 = vAR_Config['SKU']['SKU4']
#print(vAR_SKU4)

vAR_SKU5 = vAR_Config['SKU']['SKU5']
#print(vAR_SKU5)

vAR_SKU6 = vAR_Config['SKU']['SKU6']
#print(vAR_SKU6)

vAR_SKU7 = vAR_Config['SKU']['SKU7']
#print(vAR_SKU7)

vAR_SKU8 = vAR_Config['SKU']['SKU8']
#print(vAR_SKU8)

vAR_SKU9 = vAR_Config['SKU']['SKU9']
#print(vAR_SKU9)

vAR_SKU10 = vAR_Config['SKU']['SKU10']
#print(vAR_SKU10)

vAR_SKU11 = vAR_Config['SKU']['SKU11']
#print(vAR_SKU11)

vAR_SKU12 = vAR_Config['SKU']['SKU12']
#print(vAR_SKU12)

vAR_SKU13 = vAR_Config['SKU']['SKU13']
#print(vAR_SKU13)

vAR_SKU14 = vAR_Config['SKU']['SKU14']
#print(vAR_SKU14)

vAR_SKU15 = vAR_Config['SKU']['SKU15']
#print(vAR_SKU15)

vAR_SKU16 = vAR_Config['SKU']['SKU16']
#print(vAR_SKU16)

vAR_SKU17 = vAR_Config['SKU']['SKU17']
#print(vAR_SKU17)

vAR_SKU18 = vAR_Config['SKU']['SKU18']
#print(vAR_SKU18)

vAR_SKU19 = vAR_Config['SKU']['SKU19']
#print(vAR_SKU19)

vAR_SKU20 = vAR_Config['SKU']['SKU20']
#print(vAR_SKU20)

vAR_SKU21 = vAR_Config['SKU']['SKU21']
#print(vAR_SKU21)

vAR_SKU22 = vAR_Config['SKU']['SKU22']
#print(vAR_SKU22)

vAR_SKU23 = vAR_Config['SKU']['SKU23']
#print(vAR_SKU23)

vAR_SKU24 = vAR_Config['SKU']['SKU24']
#print(vAR_SKU24)

vAR_SKU25 = vAR_Config['SKU']['SKU25']
#print(vAR_SKU25)

vAR_SKU26 = vAR_Config['SKU']['SKU26']
#print(vAR_SKU26)

vAR_SKU27 = vAR_Config['SKU']['SKU27']
#print(vAR_SKU27)

vAR_FEATURE1 = vAR_Config['FEATURES']['FEATURE1']
#print(vAR_FEATURE1)

vAR_FEATURE2 = vAR_Config['FEATURES']['FEATURE2']
#print(vAR_FEATURE2)

vAR_FEATURE3 = vAR_Config['FEATURES']['FEATURE3']
#print(vAR_FEATURE3)

vAR_FEATURE4 = vAR_Config['FEATURES']['FEATURE4']
#print(vAR_FEATURE4)

vAR_FEATURE5 = vAR_Config['FEATURES']['FEATURE5']
#print(vAR_FEATURE5)

vAR_FEATURE6 = vAR_Config['FEATURES']['FEATURE6']
#print(vAR_FEATURE6)

vAR_FEATURE7 = vAR_Config['FEATURES']['FEATURE7']
#print(vAR_FEATURE7)

vAR_FEATURE8 = vAR_Config['FEATURES']['FEATURE8']
#print(vAR_FEATURE8)

vAR_FEATURE9 = vAR_Config['FEATURES']['FEATURE9']
#print(vAR_FEATURE9)

vAR_FEATURE10 = vAR_Config['FEATURES']['FEATURE10']
#print(vAR_FEATURE10)

vAR_FEATURE11 = vAR_Config['FEATURES']['FEATURE11']
#print(vAR_FEATURE11)

vAR_FEATURE12 = vAR_Config['FEATURES']['FEATURE12']
#print(vAR_FEATURE12)

vAR_FEATURE13 = vAR_Config['FEATURES']['FEATURE13']
#print(vAR_FEATURE13)

vAR_FEATURE14 = vAR_Config['FEATURES']['FEATURE14']
#print(vAR_FEATURE14)

vAR_TRAIN = vAR_Config['FILE PATH']['TRAINING_DATA_EXCEL']
#print(vAR_TRAIN)

vAR_TEST = vAR_Config['FILE PATH']['TEST_DATA_EXCEL']
#print(vAR_TEST)

vAR_CHART_XLABEL = vAR_Config['CHART LABEL']['CHART_X_LABEL']
#print(vAR_CHART_XLABEL)

vAR_CHART_YLABEL = vAR_Config['CHART LABEL']['CHART_Y_LABEL']
#print(vAR_CHART_YLABEL)

vAR_CHART_FIGURE_SIZE = vAR_Config['CHART LABEL']['CHART_FIGURE_SIZE']
#print(vAR_CHART_FIGURE_SIZE)

vAR_CHART_LABEL_FORECAST = vAR_Config['CHART LABEL']['CHART_LABEL_FORECAST']
#print(vAR_CHART_LABEL_FORECAST)

vAR_CHART_LABEL_OBSERVED = vAR_Config['CHART LABEL']['CHART_LABEL_OBSERVED']
#print(vAR_CHART_LABEL_OBSERVED)

vAR_FORECAST_COLUMN = vAR_Config['OUTPUT']['FORECAST_COLUMN']
#print(vAR_FORECAST_COLUMN)

vAR_FORECAST_COLUMN1 = vAR_Config['OUTPUT']['FORECAST_COLUMN1']
#print(vAR_FORECAST_COLUMN1)

vAR_FORECAST_PRODUCT_QUANTITY = vAR_Config['FILE PATH']['FORECAST_PRODUCT_QUANTITY']
#print(vAR_FORECAST_PRODUCT_QUANTITY)

vAR_FORECAST_SKU_QUANTITY = vAR_Config['FILE PATH']['FORECAST_SKU_QUANTITY']
#print(vAR_FORECAST_SKU_QUANTITY)


vAR_FORECAST_PRODUCT_QUANTITY_ALL = vAR_Config['FILE PATH']['FORECAST_PRODUCT_QUANTITY_ALL']
#print(vAR_FORECAST_PRODUCT_QUANTITY_ALL)

vAR_FORECAST_SKU_QUANTITY_ALL = vAR_Config['FILE PATH']['FORECAST_SKU_QUANTITY_ALL']
#print(vAR_FORECAST_SKU_QUANTITY_ALL)

vAR_FORECAST_PRODUCT_SKU_QUANTITY_ALL = vAR_Config['FILE PATH']['FORECAST_PRODUCT_SKU_QUANTITY_ALL']
#print(vAR_FORECAST_PRODUCT_SKU_QUANTITY_ALL)

# %%
#******************************************************************************************************************************

import configparser

import os

import numpy as vAR_np

import pandas as vAR_pd

import matplotlib.pylab as vAR_plt

from datetime import datetime

# %matplotlib inline

from matplotlib.pylab import rcParams

import statsmodels.api as sm

rcParams['figure.figsize'] = 12,9

#******************************************************************************************************************************

vAR_INPUT_DATA = vAR_pd.read_excel(vAR_Training_Data,sheet_name=vAR_TRAIN)

vAR_INPUT_DATA1 = vAR_pd.DataFrame(vAR_INPUT_DATA)

vAR_INPUT_DATA[vAR_FEATURE1] = vAR_pd.to_datetime(vAR_INPUT_DATA[vAR_FEATURE1])

vAR_INPUT_DATA = vAR_INPUT_DATA[[vAR_FEATURE1, vAR_FEATURE2, vAR_FEATURE3, vAR_FEATURE4, vAR_FEATURE5, vAR_FEATURE6, vAR_FEATURE7, vAR_FEATURE8, vAR_FEATURE9, vAR_FEATURE10, vAR_FEATURE11, vAR_FEATURE12,vAR_FEATURE13]]

vAR_TRAINING_DATA = vAR_INPUT_DATA.set_index([vAR_FEATURE1, vAR_FEATURE2, vAR_FEATURE3, vAR_FEATURE4, vAR_FEATURE5, vAR_FEATURE6, vAR_FEATURE7, vAR_FEATURE8, vAR_FEATURE9, vAR_FEATURE10, vAR_FEATURE11, vAR_FEATURE12])

# %%
#vAR_IndexedDataset
    
vAR_mod = sm.tsa.statespace.SARIMAX(vAR_TRAINING_DATA, order=(0, 1, 1),seasonal_order=(1, 1, 0, 12),enforce_stationarity=False,enforce_invertibility=False)

vAR_results = vAR_mod.fit()

vAR_Pred = vAR_results.get_forecast(steps=240).predicted_mean.astype(int)

#vAR_Pred.to_excel('C:/Users/durga/Desktop/temp.xlsx')

State = [vAR_State1]

City = [vAR_City2, vAR_City1, vAR_City4, vAR_City5]

SKU = [vAR_SKU1,vAR_SKU2,vAR_SKU3,vAR_SKU4,vAR_SKU5,vAR_SKU6,vAR_SKU7,vAR_SKU8,vAR_SKU9,vAR_SKU10,vAR_SKU11,vAR_SKU12,vAR_SKU13,vAR_SKU14,vAR_SKU15,vAR_SKU16,vAR_SKU17,vAR_SKU18,vAR_SKU19,vAR_SKU20,vAR_SKU21,vAR_SKU22,vAR_SKU23,vAR_SKU24,vAR_SKU25,vAR_SKU26,vAR_SKU27]

vAR_APPEND_FORCAST_DF = vAR_pd.DataFrame(columns=[vAR_FORECAST_COLUMN1])

for i in (State):
        
    for j in (City):
            
        for k in (SKU):

            vAR_results_data = vAR_results.get_forecast(steps=60).predicted_mean.astype(int)

            vAR_results_data_df = vAR_pd.DataFrame(vAR_results_data,columns=[vAR_FORECAST_COLUMN1])
            
            vAR_pred = vAR_results.get_prediction(steps=60).predicted_mean.astype(int)

            #vAR_RESULT1s_data_df = vAR_pd.DataFrame(vAR_results_data_df,columns=[vAR_FORECAST_COLUMN1])
            
            #print(vAR_RESULT1s_data_df)
            
            print(i,j,k)
            
            print(vAR_pred)
            
            #print(vAR_results_data_df)
# Out:
# C:\Users\durga\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\durga\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
import win32com.client
from pywintypes import com_error

# Path to original excel file
WB_PATH = r'C:/Users/durga/Downloads/AirPassengers.xlsx'

# PDF path when saving
PATH_TO_PDF = r'C:/Users/durga/Downloads/AirPassengers.pdf'

excel = win32com.client.Dispatch("Excel.Application")

excel.Visible = False

try:
    print('Start conversion to PDF')

    # Open
    wb = excel.Workbooks.Open(WB_PATH)

    # Specify the sheet you want to save by index. 1 is the first (leftmost) sheet.
    ws_index_list = [1]
    wb.WorkSheets(ws_index_list).Select()

    # Save
    wb.ActiveSheet.ExportAsFixedFormat(0, PATH_TO_PDF)
except com_error as e:
    print('failed.')
else:
    print('Succeeded.')
    wb.Close()
    excel.Quit()
# Out:
# Start conversion to PDF
# failed.
