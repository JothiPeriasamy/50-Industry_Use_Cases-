# %%
#********************************************************************************

## Step 1: INI File Configuration

#********************************************************************************

import configparser
import os
vAR_Config = configparser.ConfigParser(allow_no_value=True)

vAR_INI_FILE_PATH = os.getenv('FACIAL_RECOGNITION_INI_ML')
#print(vAR_INI_FILE_PATH)

vAR_Config.read(vAR_INI_FILE_PATH)

vAR_Data = vAR_Config.sections()

vAR_Config.sections()

vAR_Training_Data = vAR_Config['FILE PATH']['TRAINING_DATA']
#print(vAR_Training_Data)

vAR_Training_Data_Excel_Sheet = vAR_Config['FILE PATH']['TRAINING_DATA_EXCEL_WORKSHEET']
#print(vAR_Training_Data_Excel_Sheet)

vAR_Test_Data = vAR_Config['FILE PATH']['TEST_DATA']
#print(vAR_Test_Data)

vAR_Test_Data_Excel_Sheet = vAR_Config['FILE PATH']['TEST_DATA_EXCEL_WORKSHEET']
#print(vAR_Test_Data_Excel_Sheet)

vAR_Model_Outcome = vAR_Config['FILE PATH']['MODEL_OUTCOME']
#print(vAR_Model_Outcome)

vAR_Feature1 = vAR_Config['FEATURES']['FEATURE1']
#print(vAR_Feature1)

vAR_Feature2 = vAR_Config['FEATURES']['FEATURE2']
#print(vAR_Feature2)

vAR_Feature3 = vAR_Config['FEATURES']['FEATURE3']
#print(vAR_Feature3)

vAR_Feature4 = vAR_Config['FEATURES']['FEATURE4']
#print(vAR_Feature4)

vAR_Feature5 = vAR_Config['FEATURES']['FEATURE5']
#print(vAR_Feature5)

vAR_Feature6 = vAR_Config['FEATURES']['FEATURE6']
#print(vAR_Feature6)

vAR_Feature7 = vAR_Config['FEATURES']['FEATURE7']
#print(vAR_Feature7)

vAR_Feature8 = vAR_Config['FEATURES']['FEATURE8']
#print(vAR_Feature8)

vAR_Feature9 = vAR_Config['FEATURES']['FEATURE9']
#print(vAR_Feature9)

vAR_Feature10 = vAR_Config['FEATURES']['FEATURE10']
#print(vAR_Feature10)

vAR_Feature11 = vAR_Config['FEATURES']['FEATURE11']
#print(vAR_Feature11)

vAR_Feature12 = vAR_Config['FEATURES']['FEATURE12']
#print(vAR_Feature12)

vAR_Feature13 = vAR_Config['FEATURES']['FEATURE13']
#print(vAR_Feature13)

vAR_Feature14 = vAR_Config['FEATURES']['FEATURE14']
#print(vAR_Feature14)

vAR_Feature15 = vAR_Config['FEATURES']['FEATURE15']
#print(vAR_Feature15)

vAR_Feature16 = vAR_Config['FEATURES']['FEATURE16']
#print(vAR_Feature16)

vAR_Feature17 = vAR_Config['FEATURES']['FEATURE17']
#print(vAR_Feature17)

vAR_Feature18 = vAR_Config['FEATURES']['FEATURE18']
#print(vAR_Feature18)

vAR_Feature19 = vAR_Config['FEATURES']['FEATURE19']
#print(vAR_Feature19)

vAR_Feature20 = vAR_Config['FEATURES']['FEATURE20']
#print(vAR_Feature20)

vAR_Feature21 = vAR_Config['FEATURES']['FEATURE21']
#print(vAR_Feature21)

vAR_Feature22 = vAR_Config['FEATURES']['FEATURE22']
#print(vAR_Feature22)

vAR_Feature23 = vAR_Config['FEATURES']['FEATURE23']
#print(vAR_Feature23)

vAR_Feature24 = vAR_Config['FEATURES']['FEATURE24']
#print(vAR_Feature24)

vAR_Feature25 = vAR_Config['FEATURES']['FEATURE25']
#print(vAR_Feature25)

vAR_Label = vAR_Config['LABEL']['LABEL']
#print(vAR_Label)

#********************************************************************************
    
## Step 2: Importing the Required Libraries

#********************************************************************************

import pandas as vAR_pd

import numpy as vAR_np

from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import LabelEncoder


#********************************************************************************
    
## Step 3: Importing the Training Data

#********************************************************************************

vAR_INPUT_DATA = vAR_pd.read_excel(vAR_Training_Data,sheet_name=vAR_Training_Data_Excel_Sheet)

vAR_INPUT_DATA = vAR_pd.DataFrame(vAR_INPUT_DATA)

vAR_INPUT_DATA.head()

vAR_TRAINING_DATA = vAR_INPUT_DATA

vAR_le = LabelEncoder()


#********************************************************************************

vAR_Face_Shape_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,2])

vAR_Eye_Shape_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,3])

vAR_Eye_Size_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,4])

vAR_Eye_Colour_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,5])

vAR_Eye_Setting_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,6])

vAR_Eye_Lashes_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,7])

vAR_Eyebrow_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,8])

vAR_Hair_Texture_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,9])

vAR_Hair_Volume_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,10])

vAR_Hair_Colour_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,11])

vAR_Forehead_Shape_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,12])

vAR_Ear_Size_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,13])

vAR_Ear_Lobe_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,14])

vAR_Ear_Distance_from_Head_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,15])

vAR_Nose_Shape_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,16])

vAR_Nose_Profile_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,17])

vAR_Nose_Width_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,18])

vAR_Nose_Height_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,19])

vAR_Chin_Shape_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,20])

vAR_Chin_Prominence_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,21])

vAR_Upper_Lip_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,22])

vAR_Lower_Lip_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,23])

vAR_Teeth_Size_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,24])

vAR_Teeth_Appearnce_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,25])

vAR_Unique_Feature_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,26])

vAR_Label_Conversion = vAR_le.fit_transform(vAR_TRAINING_DATA.iloc[:,27])

#********************************************************************************

vAR_df1 = vAR_pd.DataFrame(columns=['First Name','Last Name','Face Shape','Eye Shape','Eye Size','Eye Colour','Eye Setting','Eye Lashes','Eyebrow','Hair Texture','Hair Volume','Hair Colour','Forehead Shape','Ear Size','Ear Lobe','Ear Distance from Head','Nose Shape','Nose Profile','Nose Width','Nose Height','Chin Shape','Chin Prominence','Upper Lip','Lower Lip','Teeth Size','Teeth Appearnce','Unique Feature','Gender'])

vAR_df1[vAR_Feature1] = vAR_Face_Shape_Conversion

vAR_df1[vAR_Feature2] = vAR_Eye_Shape_Conversion

vAR_df1[vAR_Feature3] = vAR_Eye_Size_Conversion

vAR_df1[vAR_Feature4] = vAR_Eye_Colour_Conversion

vAR_df1[vAR_Feature5] = vAR_Eye_Setting_Conversion

vAR_df1[vAR_Feature6] = vAR_Eye_Lashes_Conversion

vAR_df1[vAR_Feature7] = vAR_Eyebrow_Conversion

vAR_df1[vAR_Feature8] = vAR_Hair_Texture_Conversion

vAR_df1[vAR_Feature9] = vAR_Hair_Volume_Conversion

vAR_df1[vAR_Feature10] = vAR_Hair_Colour_Conversion

vAR_df1[vAR_Feature11] = vAR_Forehead_Shape_Conversion

vAR_df1[vAR_Feature12] = vAR_Ear_Size_Conversion

vAR_df1[vAR_Feature13] = vAR_Ear_Lobe_Conversion

vAR_df1[vAR_Feature14] = vAR_Ear_Distance_from_Head_Conversion

vAR_df1[vAR_Feature15] = vAR_Nose_Shape_Conversion

vAR_df1[vAR_Feature16] = vAR_Nose_Profile_Conversion

vAR_df1[vAR_Feature17] = vAR_Nose_Width_Conversion

vAR_df1[vAR_Feature18] = vAR_Nose_Height_Conversion

vAR_df1[vAR_Feature19] = vAR_Chin_Shape_Conversion

vAR_df1[vAR_Feature20] = vAR_Chin_Prominence_Conversion

vAR_df1[vAR_Feature21] = vAR_Upper_Lip_Conversion

vAR_df1[vAR_Feature22] = vAR_Lower_Lip_Conversion

vAR_df1[vAR_Feature23] = vAR_Teeth_Size_Conversion

vAR_df1[vAR_Feature24] = vAR_Teeth_Appearnce_Conversion

vAR_df1[vAR_Feature25] = vAR_Unique_Feature_Conversion

vAR_df1[vAR_Label] = vAR_Label_Conversion

vAR_TRAININNG_DATA_FEATURES = vAR_df1[[vAR_Feature1, vAR_Feature2, vAR_Feature3, vAR_Feature4, vAR_Feature5, vAR_Feature6, vAR_Feature7, vAR_Feature8, vAR_Feature9, vAR_Feature10, vAR_Feature11, vAR_Feature12, vAR_Feature13, vAR_Feature14, vAR_Feature15, vAR_Feature16, vAR_Feature17, vAR_Feature18, vAR_Feature19, vAR_Feature20, vAR_Feature21, vAR_Feature22, vAR_Feature23, vAR_Feature24, vAR_Feature25]]

vAR_TRAININNG_DATA_LABEL = vAR_df1[vAR_Label]

#********************************************************************************
    
## Step 4: Importing the Random Forest Model

vAR_MODEL = RandomForestClassifier()


#********************************************************************************
    
## Step 5: Training the Model

vAR_MODEL_TRAINING = vAR_MODEL.fit(vAR_TRAININNG_DATA_FEATURES,vAR_TRAININNG_DATA_LABEL)


#********************************************************************************
    
## Step 6: Import the Test Data

#********************************************************************************

vAR_TEST_DATA = vAR_pd.read_excel(vAR_Test_Data,sheet_name=vAR_Test_Data_Excel_Sheet)

vAR_TEST_DATA = vAR_pd.DataFrame(vAR_TEST_DATA)

vAR_TEST_DATA.head()

#********************************************************************************

vAR_Face_Shape_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,2])

vAR_Eye_Shape_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,3])

vAR_Eye_Size_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,4])

vAR_Eye_Colour_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,5])

vAR_Eye_Setting_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,6])

vAR_Eye_Lashes_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,7])

vAR_Eyebrow_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,8])

vAR_Hair_Texture_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,9])

vAR_Hair_Volume_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,10])

vAR_Hair_Colour_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,11])

vAR_Forehead_Shape_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,12])

vAR_Ear_Size_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,13])

vAR_Ear_Lobe_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,14])

vAR_Ear_Distance_from_Head_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,15])

vAR_Nose_Shape_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,16])

vAR_Nose_Profile_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,17])

vAR_Nose_Width_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,18])

vAR_Nose_Height_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,19])

vAR_Chin_Shape_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,20])

vAR_Chin_Prominence_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,21])

vAR_Upper_Lip_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,22])

vAR_Lower_Lip_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,23])

vAR_Teeth_Size_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,24])

vAR_Teeth_Appearnce_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,25])

vAR_Unique_Feature_Conversion = vAR_le.fit_transform(vAR_TEST_DATA.iloc[:,26])

#********************************************************************************

vAR_df2 = vAR_pd.DataFrame(columns=['First Name','Last Name','Face Shape','Eye Shape','Eye Size','Eye Colour','Eye Setting','Eye Lashes','Eyebrow','Hair Texture','Hair Volume','Hair Colour','Forehead Shape','Ear Size','Ear Lobe','Ear Distance from Head','Nose Shape','Nose Profile','Nose Width','Nose Height','Chin Shape','Chin Prominence','Upper Lip','Lower Lip','Teeth Size','Teeth Appearnce','Unique Feature'])

vAR_df2[vAR_Feature1] = vAR_Face_Shape_Conversion

vAR_df2[vAR_Feature2] = vAR_Eye_Shape_Conversion

vAR_df2[vAR_Feature3] = vAR_Eye_Size_Conversion

vAR_df2[vAR_Feature4] = vAR_Eye_Colour_Conversion

vAR_df2[vAR_Feature5] = vAR_Eye_Setting_Conversion

vAR_df2[vAR_Feature6] = vAR_Eye_Lashes_Conversion

vAR_df2[vAR_Feature7] = vAR_Eyebrow_Conversion

vAR_df2[vAR_Feature8] = vAR_Hair_Texture_Conversion

vAR_df2[vAR_Feature9] = vAR_Hair_Volume_Conversion

vAR_df2[vAR_Feature10] = vAR_Hair_Colour_Conversion

vAR_df2[vAR_Feature11] = vAR_Forehead_Shape_Conversion

vAR_df2[vAR_Feature12] = vAR_Ear_Size_Conversion

vAR_df2[vAR_Feature13] = vAR_Ear_Lobe_Conversion

vAR_df2[vAR_Feature14] = vAR_Ear_Distance_from_Head_Conversion

vAR_df2[vAR_Feature15] = vAR_Nose_Shape_Conversion

vAR_df2[vAR_Feature16] = vAR_Nose_Profile_Conversion

vAR_df2[vAR_Feature17] = vAR_Nose_Width_Conversion

vAR_df2[vAR_Feature18] = vAR_Nose_Height_Conversion

vAR_df2[vAR_Feature19] = vAR_Chin_Shape_Conversion

vAR_df2[vAR_Feature20] = vAR_Chin_Prominence_Conversion

vAR_df2[vAR_Feature21] = vAR_Upper_Lip_Conversion

vAR_df2[vAR_Feature22] = vAR_Lower_Lip_Conversion

vAR_df2[vAR_Feature23] = vAR_Teeth_Size_Conversion

vAR_df2[vAR_Feature24] = vAR_Teeth_Appearnce_Conversion

vAR_df2[vAR_Feature25] = vAR_Unique_Feature_Conversion

#********************************************************************************

vAR_TEST_DATA_FEATURES = vAR_df2[[vAR_Feature1, vAR_Feature2, vAR_Feature3, vAR_Feature4, vAR_Feature5, vAR_Feature6, vAR_Feature7, vAR_Feature8, vAR_Feature9, vAR_Feature10, vAR_Feature11, vAR_Feature12, vAR_Feature13, vAR_Feature14, vAR_Feature15, vAR_Feature16, vAR_Feature17, vAR_Feature18, vAR_Feature19, vAR_Feature20, vAR_Feature21, vAR_Feature22, vAR_Feature23, vAR_Feature24, vAR_Feature25]]

vAR_TEST_DATA_FEATURES

#********************************************************************************
    
## Step 7: Gender Detection (Model Prediction)

#********************************************************************************

vAR_MODEL_TEST = vAR_MODEL.predict(vAR_TEST_DATA_FEATURES)

vAR_MODEL_TEST_GENDER = vAR_pd.DataFrame(vAR_MODEL_TEST,columns=['Predicted Gender'])

vAR_MODEL_TEST_GENDER.head()

vAR_TEST_DATA['Predicted Gender'] = vAR_MODEL_TEST_GENDER

vAR_TEST_DATA['Predicted Gender'] = vAR_TEST_DATA['Predicted Gender'].replace({0: "Female"})

vAR_TEST_DATA['Predicted Gender'] = vAR_TEST_DATA['Predicted Gender'].replace({1: "Male"})

vAR_MODEL_OUTCOME_GENDER = vAR_TEST_DATA

vAR_MODEL_OUTCOME_GENDER


#********************************************************************************
    
## Step 8: Write the Model Outcome to a file

#********************************************************************************

vAR_TEST_DATA = vAR_TEST_DATA.to_excel(vAR_Model_Outcome,index=False) 

vAR_TEST_DATA = vAR_pd.read_excel(vAR_Model_Outcome)

vAR_TEST_DATA

#********************************************************************************
# Out:
# C:\Users\durga\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#   First Name Last Name Face Shape     Eye Shape Eye Size Eye Colour  \
# 0    Rosella     Burks      Round         Round    Large      Black
# 1   Angelina      Sims      Round         Round    Large       Blue
# 2   Kimberly   Mullins      Round  Round Almond    Small      Brown
# 3      Lloyd     Chuck       Oval         Round   Medium      Black
# 4       Toby  Fernando    Squared  Round Almond   Medium      Black
# 5     Kathie   Stanton      Round  Round Almond   Medium      Black
# 6    Shannon     Banks       Oval         Round    Large      Black
# 7       Cleo    Barnes    Squared        Almond    Small      Brown
# 8     Nellie     Brady    Squared        Almond   Medium      Black
# ...
