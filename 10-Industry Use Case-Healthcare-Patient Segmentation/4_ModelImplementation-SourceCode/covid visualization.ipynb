# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

import pandas as pd

# %matplotlib inline

# %%
data=pd.read_csv('us_covid19_daily.csv')

# %%
data['date']=pd.to_datetime(data['date'], format='%Y%m%d')

# %%
fig = go.Figure([go.Scatter(x=data['date'], y=data['positive'])])
fig.update_layout( xaxis_title='Month',
                   yaxis_title='COUNT',
                   plot_bgcolor='rgb(175,175,175)')
plt.savefig('positive.png')

fig.show()
# Out:
# <div>                            <div id="7739688e-40ed-47f1-8e90-e5b8036cf6b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7739688e-40ed-47f1-8e90-e5b8036cf6b4")) {                    Plotly.newPlot(                        "7739688e-40ed-47f1-8e90-e5b8036cf6b4",                        [{"type": "scatter", "x": ["2020-12-06T00:00:00", "2020-12-05T00:00:00", "2020-12-04T00:00:00", "2020-12-03T00:00:00", "2020-12-02T00:00:00", "2020-12-01T00:00:00", "2020-11-30T00:00:00", "2020-11-29T00:00:00", "2020-11-28T00:00:00", "2020-11-27T00:00:00", "2020-11-26T00:00:00", "2020-11-25T00:00:00", "2020-11-24T00:00:00", "2020-11-23T00:00:00", "2020-11-22T00:00:00", "2020-11-21T00:00:00", "2020-11-20T00:00:00", "2020-11-19T00:00:00", "2020-11-18T00:00:00", "202
# ...

# %%
data
# Out:
#           date  states  positive   negative  pending  hospitalizedCurrently  \
# 0   2020-12-06      56  14534035  161986294  13592.0               101487.0
# 1   2020-12-05      56  14357264  160813704  13433.0               101190.0
# 2   2020-12-04      56  14146191  159286709  12714.0               101276.0
# 3   2020-12-03      56  13921360  158026052  15106.0               100755.0
# 4   2020-12-02      56  13711156  156787587  14368.0               100322.0
# ..         ...     ...       ...        ...      ...                    ...
# 315 2020-01-26       2         0          0      NaN                    NaN
# 316 2020-01-25       2         0          0      NaN                    NaN
# 317 2020-01-24       2         0          0      NaN                    NaN
# 318 2020-01-23       2         0          0      NaN                    NaN
# 319 2020-01-22       2         0          0      NaN                    NaN
#
# ...

# %%
df=pd.read_csv('us_states_covid19_daily.csv')

# %%
df=df[df['date']==20201206]

# %%
scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

# %%
import chart_studio.plotly as py 
import plotly.graph_objs as go #importing graphical objects
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
data = dict(type='choropleth',
            locations = df['state'],
            locationmode = 'USA-states',colorscale = ["#f7fbff","#ebf3fb","#deebf7","#d2e3f3","#c6dbef","#b3d2e9","#9ecae1",
              "#85bcdb","#6baed6","#57a0ce","#4292c6","#3082be","#2171b5","#1361a9",
              "#08519c","#0b4083","#08306b"],
            
            z = df['positive'],
            colorbar = {'title':"Patient Count"}
            )

# %%
layout = dict(
              geo = dict(scope='usa')
             )

# %%
choromap = go.Figure(data = [data],layout = layout)
iplot(choromap)
# Out:
# <div>                            <div id="5f8f5fcb-4159-47d9-8cde-c04c59101758" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f8f5fcb-4159-47d9-8cde-c04c59101758")) {                    Plotly.newPlot(                        "5f8f5fcb-4159-47d9-8cde-c04c59101758",                        [{"colorbar": {"title": {"text": "Patient Count"}}, "colorscale": [[0.0, "#f7fbff"], [0.0625, "#ebf3fb"], [0.125, "#deebf7"], [0.1875, "#d2e3f3"], [0.25, "#c6dbef"], [0.3125, "#b3d2e9"], [0.375, "#9ecae1"], [0.4375, "#85bcdb"], [0.5, "#6baed6"], [0.5625, "#57a0ce"], [0.625, "#4292c6"], [0.6875, "#3082be"], [0.75, "#2171b5"], [0.8125, "#1361a9"], [0.875, "#08519c"], [0.9375, "#0b4083"], [1.0, "#08306b"]], "locationmode": "USA-states", "locations": ["AK", "AL", "AR"
# ...

# %%
data
# Out:
# {'type': 'choropleth',
#  'locations': 0     AK
#  1     AL
#  2     AR
#  3     AS
#  4     AZ
#  5     CA
#  6     CO
#  7     CT
#  8     DC
#  9     DE
#  10    FL
#  11    GA
#  12    GU
#  13    HI
#  14    IA
#  15    ID
#  16    IL
#  17    IN
#  18    KS
#  19    KY
#  20    LA
#  21    MA
#  22    MD
#  23    ME
#  24    MI
#  25    MN
#  26    MO
#  27    MP
#  28    MS
#  29    MT
#  30    NC
#  31    ND
#  32    NE
#  33    NH
#  34    NJ
#  35    NM
#  36    NV
#  37    NY
#  38    OH
#  39    OK
#  40    OR
#  41    PA
#  42    PR
#  43    RI
#  44    SC
#  45    SD
#  46    TN
#  47    TX
#  48    UT
#  49    VA
#  50    VI
#  51    VT
#  52    WA
#  53    WI
#  54    WV
#  55    WY
#  Name: state, dtype: object,
#  'locationmode': 'USA-states',
#  'colorscale': ['#f7fbff',
#   '#ebf3fb',
#   '#deebf7',
#   '#d2e3f3',
#   '#c6dbef',
#   '#b3d2e9',
#   '#9ecae1',
#   '#85bcdb',
#   '#6baed6',
#   '#57a0ce',
#   '#4292c6',
#   '#3082be',
#   '#2171b5',
#   '#1361a9',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=data['date'], y=data['negative'],
                    mode='lines',
                    name='negative'))
fig.add_trace(go.Scatter(x=data['date'], y=data['positive'],
                    
                    name='positive'))
fig.update_layout(plot_bgcolor='rgb(175,175,175)',
                   xaxis_title='Month',
                   yaxis_title='COUNT')
# Out:
# <div>                            <div id="96b6e945-f536-4f97-83da-7c5f9b952852" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96b6e945-f536-4f97-83da-7c5f9b952852")) {                    Plotly.newPlot(                        "96b6e945-f536-4f97-83da-7c5f9b952852",                        [{"mode": "lines", "name": "negative", "type": "scatter", "x": ["2020-12-06T00:00:00", "2020-12-05T00:00:00", "2020-12-04T00:00:00", "2020-12-03T00:00:00", "2020-12-02T00:00:00", "2020-12-01T00:00:00", "2020-11-30T00:00:00", "2020-11-29T00:00:00", "2020-11-28T00:00:00", "2020-11-27T00:00:00", "2020-11-26T00:00:00", "2020-11-25T00:00:00", "2020-11-24T00:00:00", "2020-11-23T00:00:00", "2020-11-22T00:00:00", "2020-11-21T00:00:00", "2020-11-20T00:00:00", "2020-11-19T0
# ...

# %%
fig = go.Figure([go.Scatter(x=data['date'], y=data['positiveIncrease'])])
fig.update_layout(plot_bgcolor='rgb(175,175,175)',
                   xaxis_title='Month',
                   yaxis_title='COUNT')

fig.show()
# Out:
# <div>                            <div id="f7d6313b-1a14-4257-b69b-03757002964b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7d6313b-1a14-4257-b69b-03757002964b")) {                    Plotly.newPlot(                        "f7d6313b-1a14-4257-b69b-03757002964b",                        [{"type": "scatter", "x": ["2020-12-06T00:00:00", "2020-12-05T00:00:00", "2020-12-04T00:00:00", "2020-12-03T00:00:00", "2020-12-02T00:00:00", "2020-12-01T00:00:00", "2020-11-30T00:00:00", "2020-11-29T00:00:00", "2020-11-28T00:00:00", "2020-11-27T00:00:00", "2020-11-26T00:00:00", "2020-11-25T00:00:00", "2020-11-24T00:00:00", "2020-11-23T00:00:00", "2020-11-22T00:00:00", "2020-11-21T00:00:00", "2020-11-20T00:00:00", "2020-11-19T00:00:00", "2020-11-18T00:00:00", "202
# ...
